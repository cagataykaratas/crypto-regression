# %%
#Imports

import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.subplots import make_subplots

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import matplotlib as mp

# %matplotlib inline 

import math
import random 
from datetime import timedelta
from datetime import datetime

import seaborn as sns
    
import warnings
warnings.filterwarnings('ignore')

from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# %%
# import dataset
df = pd.read_csv("assets/df.csv")
btc = pd.read_csv("assets/btc.csv")

# %%
df.set_index('date',inplace=True)
btc.set_index('date',inplace=True)

# %% [markdown]
# #### Eigth-coin data set

# %%
X = df[['volume']]
y = df['close']

# %%
from sklearn.model_selection import train_test_split
df_x_train, df_x_test, df_y_train, df_y_test = train_test_split(X,y,test_size=0.25,random_state=15)

# %%
from sklearn.linear_model import LinearRegression
df_regressor = LinearRegression()
df_regressor.fit(df_x_train, df_y_train)
df_y_pred = df_regressor.predict(df_x_test)

# %%
print(df_regressor.intercept_)
print(df_regressor.coef_)
# Out:
# 0.02104130366886678
# [0.85300232]

# %%
lin_df_pred = pd.DataFrame({'Actual':df_y_test, 'Predicted':df_y_pred})
lin_df_pred
# Out:
#               Actual  Predicted
# date
# 2018-01-17  0.000973   0.037485
# 2017-10-26  0.235847   0.030272
# 2018-04-30  0.389675   0.038864
# 2018-01-27  0.000755   0.032936
# 2014-10-15  0.000004   0.021079
# ...              ...        ...
# 2016-09-20  0.000258   0.021041
# 2016-05-18  0.006091   0.021079
# 2016-08-03  0.001294   0.021072
# 2016-05-06  0.000005   0.021150
# 2015-06-19  0.000009   0.021305
#
# [2772 rows x 2 columns]

# %%
from sklearn import metrics
print('Mean Absolute Error: ',metrics.mean_absolute_error(df_y_test,df_y_pred))
print('Mean Squared Error: ', metrics.mean_squared_error(df_y_test, df_y_pred))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(df_y_test, df_y_pred)))
print('R^2 Error: ', metrics.r2_score(df_y_test, df_y_pred))
# Out:
# Mean Absolute Error:  0.04218709172539661
# Mean Squared Error:  0.007833892633417662
# Root Mean Squared Error:  0.08850927992825194
# R^2 Error:  0.44154091522048233

# %%
df
# Out:
#                 high     close    volume    market  close_ratio    spread  \
# date
# 2014-03-30  0.000008  0.000008  0.000033  0.000605     0.345404  0.000004
# 2014-03-31  0.000007  0.000007  0.000046  0.000551     0.070657  0.000005
# 2014-04-01  0.000007  0.000007  0.000032  0.000549     0.231190  0.000003
# 2014-04-02  0.000007  0.000006  0.000058  0.000497     0.163623  0.000005
# 2014-04-03  0.000006  0.000006  0.000032  0.000498     0.902468  0.000003
# ...              ...       ...       ...       ...          ...       ...
# 2018-09-08  0.015370  0.014910  0.013091  0.009434     0.066964  0.008509
# 2018-09-09  0.014730  0.015207  0.013099  0.009620     0.422078  0.005850
# 2018-09-10  0.014364  0.015240  0.013116  0.009643     0.403226  0.002355
# 2018-09-11  0.014334  0.014507  0.013224  0.009180     0.260606  0.006268
# 2018-09-12  0.013603  0.014507  0.013621  0.009179     0.826667  0.005698
#
#             profit\loss  slug_dash  slug_ethereum  slug_litecoin  ...  \
# date                                                              ...
# 2018-09-08  0.043877  0.043882  0.051788  0.024865     0.131213  0.019107
# 2018-09-09  0.042956  0.045267  0.052193  0.025656     0.597826  0.013979
# 2018-09-10  0.042704  0.045003  0.052958  0.025509     0.428016  0.009763
# 2018-09-11  0.041722  0.043165  0.053246  0.024474     0.348649  0.014055
# 2018-09-12  0.039917  0.042580  0.055174  0.024147     0.841772  0.018006
#
#             profit\loss  slug_dash  slug_ethereum  slug_litecoin  ...  \
# date                                                              ...
# 2014-03-30     0.432013          0              0              1  ...
# 2014-03-31     0.431411          0              0              1  ...
# 2014-04-01     0.436496          0              0              1  ...
# 2014-04-02     0.422042          0              0              1  ...
# 2014-04-03     0.432682          0              0              1  ...
# ...                 ...        ...            ...            ...  ...
# 2018-09-08     0.414748          0              0              1  ...
# 2018-09-09     0.445128          0              0              1  ...
# 2018-09-10     0.431478          0              0              1  ...
# 2018-09-11     0.419098          0              0              1  ...
# 2018-09-12     0.429202          0              0              1  ...
#
#             month_name_December  month_name_February  month_name_January  \
# date
# 2014-03-30                    0                    0                   0
# 2014-03-31                    0                    0                   0
# 2014-04-01                    0                    0                   0
# 2014-04-02                    0                    0                   0
# 2014-04-03                    0                    0                   0
# ...                         ...                  ...                 ...
# 2018-09-08                    0                    0                   0
# 2018-09-09                    0                    0                   0
# 2018-09-10                    0                    0                   0
# 2018-09-11                    0                    0                   0
# 2018-09-12                    0                    0                   0
#
#             month_name_July  month_name_June  month_name_March  \
# date
# 2014-03-30                0                0                 1
# 2014-03-31                0                0                 1
# 2014-04-01                0                0                 0
# 2014-04-02                0                0                 0
# 2014-04-03                0                0                 0
# ...                     ...              ...               ...
# 2018-09-08                0                0                 0
# 2018-09-09                0                0                 0
# 2018-09-10                0                0                 0
# 2018-09-11                0                0                 0
# 2018-09-12                0                0                 0
#
#             month_name_May  month_name_November  month_name_October  \
# date
# 2014-03-30               0                    0                   0
# 2014-03-31               0                    0                   0
# 2014-04-01               0                    0                   0
# 2014-04-02               0                    0                   0
# 2014-04-03               0                    0                   0
# ...                    ...                  ...                 ...
# 2018-09-08               0                    0                   0
# 2018-09-09               0                    0                   0
# 2018-09-10               0                    0                   0
# 2018-09-11               0                    0                   0
# 2018-09-12               0                    0                   0
#
#             month_name_September
# date
# 2014-03-30                     0
# 2014-03-31                     0
# 2014-04-01                     0
# 2014-04-02                     0
# 2014-04-03                     0
# ...                          ...
# 2018-09-08                     1
# 2018-09-09                     1
# 2018-09-10                     1
# 2018-09-11                     1
# 2018-09-12                     1
#
# [1628 rows x 106 columns]

# %%
from sklearn.model_selection import train_test_split
lite_x_train, lite_x_test, lite_y_train, lite_y_test = train_test_split(X,y,test_size=0.25,random_state=15)

# %%
from sklearn.linear_model import LinearRegression
lite_regressor = LinearRegression()
lite_regressor.fit(lite_x_train, lite_y_train)
lite_y_pred = lite_regressor.predict(lite_x_test)

# %%
print(lite_regressor.intercept_)
print(lite_regressor.coef_)
# Out:
# 0.005448051236270887
# [0.79125689]

# %%
lin_lite_pred = pd.DataFrame({'Actual':lite_y_test, 'Predicted':lite_y_pred})
lin_lite_pred
# Out:
#               Actual  Predicted
# date
# 2017-01-16  0.003214   0.006660
# 2017-08-09  0.039572   0.035183
# 2017-12-02  0.079659   0.190371
# 2018-07-24  0.073596   0.049657
# 2017-07-26  0.034808   0.037575
# ...              ...        ...
# 2017-01-23  0.003165   0.005853
# 2017-03-26  0.003346   0.006029
# 2017-04-16  0.008828   0.009060
# 2016-02-28  0.002835   0.005595
# 2014-11-18  0.003107   0.006046
#
# [407 rows x 2 columns]

# %%
from sklearn import metrics
print('Mean Absolute Error: ',metrics.mean_absolute_error(lite_y_test,lite_y_pred))
print('Mean Squared Error: ', metrics.mean_squared_error(lite_y_test, lite_y_pred))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(lite_y_test, lite_y_pred)))
print('R^2 Error: ', metrics.r2_score(lite_y_test, lite_y_pred))
# Out:
# Mean Absolute Error:  0.011964835504781094
# Mean Squared Error:  0.00048461947467357577
# Root Mean Squared Error:  0.022014074467793913
# R^2 Error:  0.8042608274543491

# %%
plt.plot(lite_y_test,lite_y_pred)

# %% [markdown]
# #### Bitcoin

# %%
btc_X = btc[['volume']]
btc_y = btc['close']

# %%
from sklearn.model_selection import train_test_split
btc_x_train, btc_x_test, btc_y_train, btc_y_test = train_test_split(btc_X,btc_y,test_size=0.25,random_state=15)

# %%
from sklearn.linear_model import LinearRegression
btc_regressor = LinearRegression()
btc_regressor.fit(btc_x_train, btc_y_train)
btc_y_pred = btc_regressor.predict(btc_x_test)

# %%
print(btc_regressor.intercept_)
print(btc_regressor.coef_)
# Out:
# 0.030950681458640564
# [1.06609409]

# %%
lin_btc_pred = pd.DataFrame({'Actual':btc_y_test, 'Predicted':btc_y_pred})
lin_btc_pred
# Out:
#               Actual  Predicted
# date
# 2017-10-15  0.307675   0.160324
# 2016-05-05  0.019777   0.034210
# 2014-08-11  0.027133   0.031905
# 2016-06-03  0.026721   0.038835
# 2016-10-13  0.030594   0.034932
# ...              ...        ...
# 2017-11-18  0.439258   0.311981
# 2016-09-11  0.028871   0.035707
# 2015-12-24  0.020178   0.034644
# 2017-02-10  0.050755   0.043257
# 2015-05-28  0.007712   0.031844
#
# [459 rows x 2 columns]

# %%
from sklearn import metrics
print('Mean Absolute Error: ',metrics.mean_absolute_error(btc_y_test,btc_y_pred))
print('Mean Squared Error: ', metrics.mean_squared_error(btc_y_test, btc_y_pred))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(btc_y_test, btc_y_pred)))
print('R^2 Error: ', metrics.r2_score(btc_y_test, btc_y_pred))
# Out:
# Mean Absolute Error:  0.0284405333672495
# Mean Squared Error:  0.0019476083179162961
# Root Mean Squared Error:  0.04413171555600684
# R^2 Error:  0.945359211849917
