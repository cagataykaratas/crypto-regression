# %%
#Imports

import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.subplots import make_subplots

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import matplotlib as mp

# %matplotlib inline 

import math
import random 
from datetime import timedelta
from datetime import datetime

import seaborn as sns
    
import warnings
warnings.filterwarnings('ignore')

from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# %%
# import dataset
df = pd.read_csv("assets/df.csv")
btc = pd.read_csv("assets/btc.csv")

# %%
df.set_index('date',inplace=True)

# %%
df
# Out:
#                 high     close    volume    market  close_ratio    spread  \
# date
# 2014-03-30  0.000008  0.000008  0.000033  0.000605     0.345404  0.000004
# 2014-03-31  0.000007  0.000007  0.000046  0.000551     0.070657  0.000005
# 2014-04-01  0.000007  0.000007  0.000032  0.000549     0.231190  0.000003
# 2014-04-02  0.000007  0.000006  0.000058  0.000497     0.163623  0.000005
# 2014-04-03  0.000006  0.000006  0.000032  0.000498     0.902468  0.000003
# ...              ...       ...       ...       ...          ...       ...
# 2018-09-08  0.015370  0.014910  0.013091  0.009434     0.066964  0.008509
# 2018-09-09  0.014730  0.015207  0.013099  0.009620     0.422078  0.005850
# 2018-09-10  0.014364  0.015240  0.013116  0.009643     0.403226  0.002355
# 2018-09-11  0.014334  0.014507  0.013224  0.009180     0.260606  0.006268
# 2018-09-12  0.013603  0.014507  0.013621  0.009179     0.826667  0.005698
#
#             profit\loss  slug_dash  slug_ethereum  slug_litecoin  ...  \
# ...

# %%
btc.set_index('date',inplace=True)

# %%
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model

# %%
y = btc[['close']]

# %%
x = btc[['high']]

# %%
btc_X_train, btc_X_test, btc_y_train, btc_y_test = train_test_split(x, y, test_size=0.25, random_state=0)
print(btc_X_train.shape, btc_y_train.shape)
print(btc_X_test.shape, btc_y_test.shape)
# Out:
# (1377, 1) (1377, 1)
# (459, 1) (459, 1)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(btc_X_train, btc_y_train)
# Out:
# LinearRegression()

# %%
prediction = lr.predict(btc_X_test)

# %%
prediction
# Out:
# array([[1.24276181e-02],
#        [2.44312367e-03],
#        [2.86212217e-02],
#        [9.80710844e-03],
#        [4.19818266e-01],
#        [3.40082534e-02],
#        [3.62351680e-01],
#        [6.15373796e-02],
#        [7.76513855e-03],
#        [4.17817965e-01],
#        [2.35818648e-02],
#        [1.26510650e-03],
#        [2.10795454e-01],
#        [1.42226336e-01],
#        [2.17093448e-03],
#        [7.59543355e-03],
#        [5.02112239e-02],
#        [2.75352199e-02],
#        [3.42270747e-01],
#        [2.35488878e-01],
#        [4.90257472e-01],
#        [1.65462703e-02],
#        [1.35666288e-01],
#        [8.11226241e-03],
#        [3.21679460e-02],
#        [4.42498419e-01],
#        [1.78854725e-03],
#        [1.42815054e-01],
#        [1.42501888e-01],
#        [6.15886217e-02],
#        [1.81397341e-02],
#        [1.67727273e-02],
#        [4.91779046e-01],
#        [3.13491745e-02],
#        [4.66821313e-02],
#        [2.85176355e-02],
#        [1.99546960e-02],
# ...

# %%
btc[['close']]
# Out:
#                close
# date
# 2013-08-09  0.000000
# 2013-08-10  0.000011
# 2013-08-11  0.000126
# 2013-08-12  0.000220
# 2013-08-13  0.000355
# ...              ...
# 2018-08-14  0.364238
# 2018-08-15  0.363700
# 2018-08-16  0.364234
# 2018-08-17  0.363002
# 2018-08-18  0.363505
#
# [1836 rows x 1 columns]

# %%
btc_X_train = btc_X_train.sort_index()

# %%
btc_y_train = btc_y_train.sort_index()

# %%
btc_y_train
# Out:
#                close
# date
# 2013-08-09  0.000000
# 2013-08-11  0.000126
# 2013-08-12  0.000220
# 2013-08-16  0.000355
# 2013-08-17  0.000613
# ...              ...
# 2018-08-09  0.369612
# 2018-08-10  0.367186
# 2018-08-12  0.364334
# 2018-08-13  0.363615
# 2018-08-17  0.363002
#
# [1377 rows x 1 columns]

# %%
btc_X_train
# Out:
#                 high
# date
# 2013-08-09  0.000102
# 2013-08-11  0.000071
# 2013-08-12  0.000226
# 2013-08-16  0.000462
# 2013-08-17  0.000542
# ...              ...
# 2018-08-09  0.366679
# 2018-08-10  0.363663
# 2018-08-12  0.359735
# 2018-08-13  0.358508
# 2018-08-17  0.357873
#
# [1377 rows x 1 columns]

# %%
plt.scatter(btc_X_train,btc_y_train)
plt.plot(btc_X_test, lr.predict(btc_X_test))

# %%
btc_y_test
# Out:
#                close
# date
# 2015-01-02  0.012159
# 2013-10-01  0.001683
# 2014-03-20  0.027843
# 2015-01-13  0.007051
# 2018-06-02  0.430226
# ...              ...
# 2017-09-22  0.213382
# 2016-04-27  0.019588
# 2016-06-01  0.024872
# 2017-02-16  0.052976
# 2015-09-08  0.008068
#
# [459 rows x 1 columns]

# %% [markdown]
# #### Eight-coin
